# %% [markdown]
# # Import Library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# # Code

# %%
def getdataurl(url):
    data = []
    response = requests.get(url) # Send a GET request to the URL
    soup = BeautifulSoup(response.content, 'html.parser')
    comics = soup.find_all('div', class_='bs')
    
    for comic in comics:
        # raw data comics
        raw_title = comic.find('div', class_='tt').text
        title = re.sub(r'[^a-zA-Z0-9\s]', '', raw_title.replace('\n', ' ').replace('\t', ' ')).strip()
        title = re.sub(r'\s+', ' ', title)
        
        img = comic.find('img', class_='ts-post-image').get('src')
        
        raw_rate = comic.find('div', class_='numscore').text.replace(',', '.').replace('..', '.').strip()
        rate = float(raw_rate) if re.match(r'^\d+(\.\d+)?$', raw_rate) else 0.0
        
        raw_type = comic.find('span', class_='type')
        type = raw_type['class'][1]
        
        # sub-comics to get details
        soup = BeautifulSoup((requests.get(comic.find('a').get('href'))).content, 'html.parser')
        raw_description = soup.find('div', class_="entry-content").text.strip()
        description = re.sub(r'[^a-zA-Z0-9\s]', '', raw_description)
        raw_alt_title = soup.find('div',class_='seriestualt')
        alt_title = raw_alt_title.text.strip() if raw_alt_title and raw_alt_title.text.strip() else ""
        
        # Extract genres
        raw_genre = soup.find('div', class_='seriestugenre')
        if raw_genre:
            genres = [a.text.strip() for a in raw_genre.find_all('a')]
            genre = ', '.join(genres)
        else:
            genre = ""        
        
        released = "-"
        author = "-"
        artist = "-"
        table = (soup.find('table', class_='infotable'))
        
        for row in table.find_all('tr'):
            cells = row.find_all('td')
            if len(cells) > 1:
                key = cells[0].text.strip()
                value = cells[1].text.strip()
                if key == 'Released':
                    released = value
                elif key == 'Author':
                    author = value
                elif key == 'Artist':
                    artist = value
        
        data.append({
            'title': title,
            'alt_title': alt_title,
            'type': type,
            'description': description,
            'genre': genre,
            'author':author,
            'artist':artist,
            'rate': rate,
            'image': img,
            'released': released,
        })
    return data

# %%
url = 'https://westmanga.fun/manga/'

response = requests.get(url)

if response.status_code == 200:
    json = []
    url += "?page"
    
    soup = BeautifulSoup(response.content, 'html.parser') # Parse the HTML content of the page
    comics = soup.find_all('div', class_='bs')
    last_page = 301
    
    # get data manually 300 page's
    indexNum = 201 # 100 # 0
    last_page = 315 # 201 # 100
    
    for i in range(indexNum,last_page):
        url_page = url + "=" + str(i) # Build the URL for the current page
        getdata = getdataurl(url_page)
        json = json + getdata
    df = pd.DataFrame(json)
else:
    print(f'Failed to retrieve the webpage. Status code: {response.status_code}')

# %%
df.head(5)
# Out:
#                                                title  \
# 0                  The Crazy Genius Composer Returns
# 1                                           The Crow
# 2               The Crown Prince That Sells Medicine
# 3                                The Cuckoos Fiancee
# 4  The Cursed Strongest Player Dominates Again in...
#
#                                            alt_title    type  \
# 0                                                     Manhwa
# 1           Chu Wu, Chǔ Wū, Clear Crow, The Crow, 楚乌  Manhua
# 2              Crown Prince Sells Medicine, 약 파는 황태자  Manhwa
# 3  A Couple of Cuckoos, Cuckoo no Iinazuke, Kakko...   Manga
# 4  The Cursed Strongest Player Rules the World; 呪...   Manga
#
#                                          description  \
# 0  Sukses kehormatan keluarga Min Hyunseung bla b...
# 1  Orangorang menjadi hantu saat meninggal dan ak...
# 2  Oleh Penulis yang membawakan Anda \nSaya putra...
# 3  Komedi romantis tentang Nagi pergi yang harus ...
# 4  Di dunia yang dihuni oleh berbagai ras seperti...
#
#                                           genre                 author artist  \
# 0                                         Drama                      -      -
# 1       Action, Drama, Fantasy, Horror, Shounen                 Mo Fei      -
# 2            Action, Adventure, Comedy, Fantasy  BK_Moon, LEE Hyun-Min      -
# 3  Comedy, Harem, Romance, School life, Shounen         Miki Yoshikawa      -
# 4                         Action, Fantasy, Game                      -      -
#
#    rate                                              image released
# 0  7.00  https://westmanga.fun/wp-content/uploads/2024/...        -
# 1  7.11  https://westmanga.fun/wp-content/uploads/2023/...        -
# 2  7.20  https://westmanga.fun/wp-content/uploads/2023/...        -
# 3  7.60  https://westmanga.fun/wp-content/uploads/2021/...        -
# 4  7.00  https://westmanga.fun/wp-content/uploads/2024/...        -

# %%
df.to_csv('data/westmanga.csv', index=False, encoding='utf-8')
